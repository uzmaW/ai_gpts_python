# %%
# !pip install langchain_google
from langchain_google.llms import GoogleGemini
# Out:
# ERROR: Could not find a version that satisfies the requirement langchain_google (from versions: none)
# ERROR: No matching distribution found for langchain_google
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1fad0e5425c5> in <cell line: 2>()
#       1 get_ipython().system('pip install langchain_google')
# ----> 2 from langchain_google.llms import GoogleGemini
#
# ModuleNotFoundError: No module named 'langchain_google'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install google-auth google-auth-oauthlib google-auth-httplib2 langchain langchain_community requests
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 25.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 2.4 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain_google_genai
from IPython.display import display
from IPython.display import Markdown
import textwrap


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
import os
from google.colab import userdata
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

from langchain_google_genai import ChatGoogleGenerativeAI


llm = ChatGoogleGenerativeAI(model="gemini-pro")
result = llm.invoke("What is the best practice to keep fit?")
to_markdown(result.content)
# Out:
# > **Best Practices for Staying Fit:**
# >
# > **1. Establish a Regular Exercise Routine:**
# >
# > * Aim for at least 150 minutes of moderate-intensity aerobic activity or 75 minutes of vigorous-intensity aerobic activity per week.
# > * Choose activities you enjoy to make it more sustainable.
# > * Incorporate resistance training 2-3 times per week to build muscle mass.
# >
# > **2. Focus on a Balanced Diet:**
# >
# > * Consume a diet rich in fruits, vegetables, whole grains, and lean protein.
# > * Limit processed foods, sugary drinks, and unhealthy fats.
# > * Stay hydrated by drinking plenty of water throughout the day.
# >
# > **3. Get Enough Sleep:**
# >
# > * Aim for 7-9 hours of quality sleep each night.
# > * Sleep deprivation can lead to hormonal imbalances that make it harder to lose weight and maintain fitness.
# >
# > **4. Manage Stress:**
# >
# > * Stress can release hormones that promote weight gain and inflammation.
# ...

# %%
# !pip install langchain langchain_community unstructured
# !python -m nltk.downloader punkt
# !pip install --upgrade nltk
# Out:
# ...
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %%
from langchain.document_loaders import UnstructuredURLLoader

urls = ['https://www.aljazeera.com/news/2024/5/5/india-calls-canada-arrests-over-sikh-activist-murder-political-compulsion']# put your articles
loaders = UnstructuredURLLoader(urls=urls)# now we are loading the website.
data = loaders.load()

from langchain import PromptTemplate
llm_prompt_template = """find all the contridiction and factual mistakes in this following:
"{data}"
""" # you can improve the propmt by expressing your needs more proper
llm_prompt = PromptTemplate.from_template(llm_prompt_template)

chain= llm_prompt | llm
response= chain.invoke(input= data)
response
# Out:
# AIMessage(content='**Contradictions:**\n\n* The article states that the Canadian police arrested three Indian citizens for the murder of Hardeep Singh Nijjar. However, in a later paragraph, it says that the suspects "apparently are Indians of some kind of gang background." This is a contradiction because it is unclear if the suspects are Indian citizens or members of an Indian gang.\n\n* The article states that Hardeep Singh Nijjar was wanted by Indian authorities for alleged terrorism and conspiracy to commit murder. However, in a later paragraph, it says that Nijjar had denied these allegations. This is a contradiction because it is unclear if Nijjar was actually wanted for these crimes.\n\n* The article states that India has sought to persuade Ottawa not to grant Sikh separatists visas or political legitimacy. However, in a later paragraph, it says that the Sikh diaspora - whose largest community is in Canada - retains support for a separate Sikh state among a vocal minority. This
# ...

# %%
# !pip install google-cloud-aiplatform

# %%
prompt = "Write a summary of the French Revolution."
summary = llm(prompt)
print(summary)

# %%
# prompt: mount drive , export link in bash

from google.colab import drive
drive.mount('/content/drive')

# !ls 'https://drive.google.com/file/d/1Gk9nJzH5foxEPzQM1yH-laUJteubW4rY/view?usp=drive_link'
GOOGLE_KEY_FILE=userdata.get('GOOGLE_APPLICATION_CREDENTIALS')

# Export the link to the current directory in bash
# !echo "To access your Google Drive, use this link: $(readlink -f '/content/drive/My Drive/Colab Notebooks/'+GOOGLE_KEY_FILE)"

# %%
# !export GOOGLE_APPLICATION_CREDENTIALS='/content/drive/My Drive/Colab Notebooks/'+GOOGLE_KEY_FILE

# %%
# !pip install google-cloud-texttospeech

from google.cloud import texttospeech

# Create a Text-to-Speech client
client = texttospeech.TextToSpeechClient()

# Set the text to be synthesized
input_text = "This is a text to be synthesized."
voice_params = texttospeech.VoiceSelectionParams(
    name="en-US-Standard-A",
    language_code="en-US",
)
audio_config = texttospeech.AudioConfig(
    audio_encoding=texttospeech.AudioEncoding.MP3,
)
response = client.synthesize_speech(
        input=input_text,
        voice=voice_params,
        audio_config=audio_config,
    )
voices = sorted(response.voices, key=lambda voice: voice.name)


# Write the synthesized audio to a file
filename = f"{voices}.wav"
with open(filename, "wb") as out:
    out.write(response.audio_content)
    print(f'Generated speech saved to "{filename}"')
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-21b601195108> in <cell line: 17>()
#      15     audio_encoding=texttospeech.AudioEncoding.MP3,
#      16 )
# ---> 17 response = client.synthesize_speech(
#      18         input=input_text,
#      19         voice=voice_params,
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/texttospeech_v1/services/text_to_speech/client.py in synthesize_speech(self, request, input, voice, audio_config, retry, timeout, metadata)
#     887             # request, apply these.
#     888             if input is not None:
# --> 889                 request.input = input
#     890             if voice is not None:
#     891                 request.voice = voice
#
# /usr/local/lib/python3.10/dist-packages/proto/message.py in __setattr__(self, key, value)
#     942         # Merge in the value being set.
# ...
